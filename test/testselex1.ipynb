# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome()
driver.get('https://google.com')
# r = driver.execute_script('return 100*50')
# print(r)
driver.get("https://www.youtube.com/c/paikscuisine/videos")
all_videos = driver.find_elements(By.ID, "dismissible")
print(all_videos)

time.sleep(2)
datas = []
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-1-b86037f5494a> in <module>
#       7 # print(r)
#       8 driver.get("https://www.youtube.com/c/paikscuisine/videos")
# ----> 9 all_videos = driver.find_elements(By.ID, "dismissible")
#      10 print(all_videos)
#      11
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_elements(self, by, value)
#     770         # Return empty list if driver returns null
#     771         # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 772         return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#     773
#     774     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     346         response = self.command_executor.execute(driver_command, params)
#     347         if response:
# --> 348             self.error_handler.check_response(response)
#     349             response["value"] = self._unwrap_value(response.get("value", None))
#     350             return response
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=119.0.6045.199)
# Stacktrace:
# 0   chromedriver                        0x00000001013b2d28 chromedriver + 4795688
# 1   chromedriver                        0x00000001013aa2b3 chromedriver + 4760243
# 2   chromedriver                        0x0000000100f8388d chromedriver + 407693
# 3   chromedriver                        0x0000000100f57758 chromedriver + 227160
# 4   chromedriver                        0x0000000100fff50f chromedriver + 914703
# 5   chromedriver                        0x00000001010150e6 chromedriver + 1003750
# 6   chromedriver                        0x0000000100ff9a73 chromedriver + 891507
# 7   chromedriver                        0x0000000100fc4143 chromedriver + 672067
# 8   chromedriver                        0x0000000100fc531e chromedriver + 676638
# 9   chromedriver                        0x0000000101373795 chromedriver + 4536213
# 10  chromedriver                        0x0000000101378853 chromedriver + 4556883
# 11  chromedriver                        0x0000000101359001 chromedriver + 4427777
# 12  chromedriver                        0x000000010137959d chromedriver + 4560285
# 13  chromedriver                        0x000000010134a48c chromedriver + 4367500
# 14  chromedriver                        0x00000001013990e8 chromedriver + 4690152
# 15  chromedriver                        0x000000010139929e chromedriver + 4690590
# 16  chromedriver                        0x00000001013a9eee chromedriver + 4759278
# 17  libsystem_pthread.dylib             0x00007ff80b68f514 _pthread_start + 125
# 18  libsystem_pthread.dylib             0x00007ff80b68b02f thread_start + 15

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import urllib.request

# chrome_options = webdriver.ChromeOptions()
# chrome_options.binary = 'C://chromedriver_win32/chromedriver.exe' # 드라이버 실행파일 경로
query = '춘식이'
driver = webdriver.Chrome()
driver.get(f'https://www.google.com/imghp')
# 구글 이미지 검색창 이름이 : q
search_bar = driver.find_element(By.NAME,"q")
# 검색 키워드를 춘식이 설정
search_bar.send_keys(query)
# 전달. 
search_bar.submit()
# 잠시 대기 시간 ms 1000ms = 1초 
PAUSE_TIME = 10
# 현재 문서의 스크롤의 높이를 표시. 
last_hegiht = driver.execute_script("return window.scrollY")
print(f"처음 last_hegiht : {last_hegiht}")
new_height = 0

interval = 2
prev_height = driver.execute_script("return document.body.scrollHeight")

    #  결과 더보기 버튼 .LZ4I
    #     resultMoreBtn = driver.find_element(By.CSS_SELECTOR,".LZ4I")
    #     resultMoreBtn.click()
    #     continue

while True:
    #화면 가장 아래로 스크롤 내리기
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(interval)

    curr_height = driver.execute_script("return document.body.scrollHeight")
    if curr_height == prev_height:
        break
    
    prev_height = curr_height


# while True :
#     # 스크롤 50px 아래로 이동 수행. 
#     driver.execute_script("window.scrollTo(0,500)")
#     last_hegiht2 = driver.execute_script("return document.body.scrollHeight")
#     print(f"스크롤 이동 명령후 길이 조회 : {last_hegiht2}")
#     # 2 ms 대기
#     time.sleep(PAUSE_TIME)
#     # 이동 후,  스크롤 높이 
#     new_height = driver.execute_script("return document.body.scrollHeight")
#     print(f"반복 new_height : {new_height}")
#     # 스크롤 이동 후 높이가, 크다면 이동했다면
#     if new_height - last_hegiht > 0 :
#         # 지난 높이에 대입.
#         last_hegiht = new_height
#         # 다시 반복문으로 돌아가 다시, 50px 내림 
 
#         continue
#     # elif new_height - last_hegiht == 0 :
#     #     # 결과 더보기 버튼 .LZ4I
#     #     resultMoreBtn = driver.find_element(By.CSS_SELECTOR,".LZ4I")
#     #     resultMoreBtn.click()
#     #     continue
#     else :
#         break
#     # 해당 스크롤을 다 내린후, 해당 이미지의 CSS_SELECTOR 를 이용해, 해당 클래스 모두를
#     # 추출해서 리스트에 담음
img_elements = driver.find_elements(By.CSS_SELECTOR,".rg_i")
# 다시 이미지만 추출해서 담음 임시 리스트 
imgs = []
# enumerate 함수 이용하면 해당 인덱스도 같이 추출 가능. 
for idx, img in enumerate(img_elements) :
    print(f"{query} : {idx+1}/{len(img_elements)} proceed...")
    try :
        # 이미지 클릭
        img.click()
        # 잠시 대기 
        time.sleep(PAUSE_TIME)
        # 이부분에서 에러나면, 직접 개발자 도구 활용해서 XPATH 추출한 뒤에 변경
        
        img_src = img.get_attribute('src')
        img_alt = img.get_attribute('alt')
        imgs.append({
            'alt' : img_alt,
            'src' : img_src
        })
        
    except :
        print(f'err in {idx}')
        pass
driver.close()
save_path = f'C:\ccestcrawl\{query}'
import os
if not os.path.exists(save_path):
    os.mkdir(save_path)
total_N = len(imgs)
for idx, one in enumerate(imgs):
    src = one['src']
    alt = one['alt']
    urllib.request.urlretrieve(src,  f"{save_path}\{query}_{idx}.png")
    print(idx, alt)
print('done')
# Out:
# 처음 last_hegiht : 0
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-2-56837da35a5f> in <module>
#      35     time.sleep(interval)
#      36
# ---> 37     curr_height = driver.execute_script("return document.body.scrollHeight")
#      38     if curr_height == prev_height:
#      39         break
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     406         command = Command.W3C_EXECUTE_SCRIPT
#     407
# --> 408         return self.execute(command, {"script": script, "args": converted_args})["value"]
#     409
#     410     def execute_async_script(self, script: str, *args):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     346         response = self.command_executor.execute(driver_command, params)
#     347         if response:
# --> 348             self.error_handler.check_response(response)
#     349             response["value"] = self._unwrap_value(response.get("value", None))
#     350             return response
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=119.0.6045.199)
# Stacktrace:
# 0   chromedriver                        0x000000010d423d28 chromedriver + 4795688
# 1   chromedriver                        0x000000010d41b2b3 chromedriver + 4760243
# 2   chromedriver                        0x000000010cff488d chromedriver + 407693
# 3   chromedriver                        0x000000010cfc8758 chromedriver + 227160
# 4   chromedriver                        0x000000010d07050f chromedriver + 914703
# 5   chromedriver                        0x000000010d0860e6 chromedriver + 1003750
# 6   chromedriver                        0x000000010d06aa73 chromedriver + 891507
# 7   chromedriver                        0x000000010d035143 chromedriver + 672067
# 8   chromedriver                        0x000000010d03631e chromedriver + 676638
# 9   chromedriver                        0x000000010d3e4795 chromedriver + 4536213
# 10  chromedriver                        0x000000010d3e9853 chromedriver + 4556883
# 11  chromedriver                        0x000000010d3ca001 chromedriver + 4427777
# 12  chromedriver                        0x000000010d3ea59d chromedriver + 4560285
# 13  chromedriver                        0x000000010d3bb48c chromedriver + 4367500
# 14  chromedriver                        0x000000010d40a0e8 chromedriver + 4690152
# 15  chromedriver                        0x000000010d40a29e chromedriver + 4690590
# 16  chromedriver                        0x000000010d41aeee chromedriver + 4759278
# 17  libsystem_pthread.dylib             0x00007ff80b68f514 _pthread_start + 125
# 18  libsystem_pthread.dylib             0x00007ff80b68b02f thread_start + 15
