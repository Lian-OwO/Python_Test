# %%
# pip install numpy
# pip install pandas
# pip install matplot
# matplotlib 공식 문서
# https://matplotlib.org/stable/index.html
import numpy as np
import pandas as pd 
import matplotlib

#50개 랜덤한 수 생성 , 0 ~ 1 사이 소수 중에서, 
data = np.random.rand(50)
print(type(data))
print(f"출력해보기 data : {data} ")

# 넘파이 -> 판다스의 시리즈 자료형으로 변환 
seri = pd.Series(data)
print(type(seri))
print(f"출력해보기 seri : \n {seri} ")

# 변환된 pd(테이블), 차트 그리기. 
# matplotlib 으로 스타일 변경해보기. 
matplotlib.style.use("ggplot")
seri.plot()
# Out:
# <class 'numpy.ndarray'>
# 출력해보기 data : [0.75150666 0.39477511 0.80726112 0.09714135 0.64546809 0.49741837
#  0.77586004 0.58533418 0.02024635 0.05390849 0.18823876 0.62527468
#  0.00861692 0.54689423 0.77817603 0.18154656 0.68112825 0.90434164
#  0.76459393 0.4526566  0.67198807 0.71914672 0.92965465 0.44571246
#  0.92754228 0.62825932 0.72848331 0.0242701  0.09495087 0.47764031
#  0.1737197  0.96932802 0.2705295  0.44059546 0.66373338 0.06496907
#  0.9977168  0.4365129  0.64721948 0.76102634 0.80436236 0.19948238
#  0.6055441  0.57541192 0.49515273 0.56318792 0.86029017 0.88804637
#  0.95796797 0.21482687]
# <class 'pandas.core.series.Series'>
# 출력해보기 seri :
#  0     0.751507
# 1     0.394775
# 2     0.807261
# 3     0.097141
# 4     0.645468
# 5     0.497418
# 6     0.775860
# 7     0.585334
# 8     0.020246
# 9     0.053908
# 10    0.188239
# 11    0.625275
# 12    0.008617
# 13    0.546894
# 14    0.778176
# 15    0.181547
# 16    0.681128
# 17    0.904342
# 18    0.764594
# 19    0.452657
# 20    0.671988
# 21    0.719147
# 22    0.929655
# 23    0.445712
# 24    0.927542
# 25    0.628259
# 26    0.728483
# 27    0.024270
# 28    0.094951
# 29    0.477640
# 30    0.173720
# 31    0.969328
# 32    0.270530
# 33    0.440595
# 34    0.663733
# 35    0.064969
# 36    0.997717
# 37    0.436513
# 38    0.647219
# 39    0.761026
# 40    0.804362
# 41    0.199482
# 42    0.605544
# 43    0.575412
# 44    0.495153
# 45    0.563188
# 46    0.860290
# 47    0.888046
# 48    0.957968
# 49    0.214827
# dtype: float64
# <Axes: >

# %%
# matplotlib 공식 문서 예제 가져오기. 
import matplotlib.pyplot as plt
import numpy as np


species = ('Adelie', 'Chinstrap', 'Gentoo')
sex_counts = {
    'Male': np.array([73, 34, 61]),
    'Female': np.array([73, 34, 58]),
}
width = 0.6  # the width of the bars: can also be len(x) sequence


fig, ax = plt.subplots()
bottom = np.zeros(3)

for sex, sex_count in sex_counts.items():
    p = ax.bar(species, sex_count, width, label=sex, bottom=bottom)
    bottom += sex_count

    ax.bar_label(p, label_type='center')

ax.set_title('Number of penguins by sex')
ax.legend()

plt.show()
